# %% [markdown]
# ### Load the data

# %%
import requests
import json

# Download the data
resp = requests.get('https://raw.githubusercontent.com/weaviate-tutorials/quickstart/main/data/jeopardy_tiny.json')
data = json.loads(resp.text)  # Load data

# Parse the JSON and preview it
print(type(data),  len(data))
print(json.dumps(data[0], indent=2))
# Out:
# <class 'list'> 10
# {
#   "Category": "SCIENCE",
#   "Question": "This organ removes excess glucose from the blood & stores it as glycogen",
#   "Answer": "Liver"
# }

# %%
def json_print(data):
    print(json.dumps(data, indent=2))

# %%
#Print out the rest of the data

json_print(data)
# Out:
# [
#   {
#     "Category": "SCIENCE",
#     "Question": "This organ removes excess glucose from the blood & stores it as glycogen",
#     "Answer": "Liver"
#   },
#   {
#     "Category": "ANIMALS",
#     "Question": "It's the only living mammal in the order Proboseidea",
#     "Answer": "Elephant"
#   },
#   {
#     "Category": "ANIMALS",
#     "Question": "The gavial looks very much like a crocodile except for this bodily feature",
#     "Answer": "the nose or snout"
#   },
#   {
#     "Category": "ANIMALS",
#     "Question": "Weighing around a ton, the eland is the largest species of this animal in Africa",
#     "Answer": "Antelope"
#   },
#   {
#     "Category": "ANIMALS",
#     "Question": "Heaviest of all poisonous snakes is this North American rattlesnake",
#     "Answer": "the diamondback rattler"
#   },
#   {
#     "Category": "SCIENCE",
#     "Question": "2000 news: the Gunnison sage grouse isn't just another northern sage grouse, but a new one of this classification",
#     "Answer": "species"
#   },
#   {
#     "Category": "SCIENCE",
#     "Question": "A metal that is ductile can be pulled into this while cold & under pressure",
#     "Answer": "wire"
#   },
#   {
#     "Category": "SCIENCE",
#     "Question": "In 1953 Watson & Crick built a model of the molecular structure of this, the gene-carrying substance",
#     "Answer": "DNA"
#   },
#   {
#     "Category": "SCIENCE",
#     "Question": "Changes in the tropospheric layer of this are what gives us weather",
#     "Answer": "the atmosphere"
#   },
#   {
#     "Category": "SCIENCE",
#     "Question": "In 70-degree air, a plane traveling at about 1,130 feet per second breaks it",
#     "Answer": "Sound barrier"
#   }
# ]

# %% [markdown]
# ### Now we're going to initialize Weaviate - our vector DB

# %%
import weaviate
print(weaviate.__file__)
# Out:
# c:\DematicDev\projects\courses\intro-ai-native-vector-dbs\.venv\Lib\site-packages\weaviate\__init__.py

# %%
import weaviate
from weaviate import EmbeddedOptions
from dotenv import load_dotenv
import os

load_dotenv()  # reads .env into os.environ


#Start up an instance of Weaviate

client = weaviate.Client(embedded_options=EmbeddedOptions(),
                         additional_headers={
                             "X-OpenAI-Api-Key": os.environ["OPENAI_API_KEY"]
                         })
# Out:
# ---------------------------------------------------------------------------
# WeaviateStartUpError                      Traceback (most recent call last)
# Cell In[2], line 11
#       6 load_dotenv()  # reads .env into os.environ
#       9 #Start up an instance of Weaviate
# ---> 11 client = weaviate.Client(embedded_options=EmbeddedOptions(),
#      12                          additional_headers={
#      13                              "X-OpenAI-Api-Key": os.environ["OPENAI_API_KEY"]
#      14                          })
#
# File c:\DematicDev\projects\courses\intro-ai-native-vector-dbs\.venv\Lib\site-packages\weaviate\client.py:148, in Client.__init__(self, url, auth_client_secret, timeout_config, proxies, trust_env, additional_headers, startup_period, embedded_options, additional_config)
#      66 """
#      67 Initialize a Client class instance.
#      68
#    (...)    145     If arguments are of a wrong data type.
#     146 """
#     147 config = Config() if additional_config is None else additional_config
# --> 148 url, embedded_db = self.__parse_url_and_embedded_db(url, embedded_options)
#     150 self._connection = Connection(
#     151     url=url,
#     152     auth_client_secret=auth_client_secret,
#    (...)    160     connection_config=config.connection_config,
#     161 )
#     162 self.classification = Classification(self._connection)
#
# File c:\DematicDev\projects\courses\intro-ai-native-vector-dbs\.venv\Lib\site-packages\weaviate\client.py:287, in Client.__parse_url_and_embedded_db(url, embedded_options)
#     282     raise TypeError(
#     283         f"URL is not expected to be set when using embedded_options but URL was {url}"
#     284     )
#     286 if embedded_options is not None:
# --> 287     embedded_db = EmbeddedDB(options=embedded_options)
#     288     embedded_db.start()
#     289     return f"http://localhost:{embedded_db.options.port}", embedded_db
#
# File c:\DematicDev\projects\courses\intro-ai-native-vector-dbs\.venv\Lib\site-packages\weaviate\embedded.py:58, in EmbeddedDB.__init__(self, options)
#      56 self.process: Optional[subprocess.Popen[bytes]] = None
#      57 self.ensure_paths_exist()
# ---> 58 self.check_supported_platform()
#      59 self._parsed_weaviate_version = ""
#      60 # regular expression to detect a version number: v[one digit].[1-2 digits].[1-2 digits]
#      61 # optionally there can be a "-rc/alpha/beta.[1-2 digits]"
#      62 # nothing in front or back
#
# File c:\DematicDev\projects\courses\intro-ai-native-vector-dbs\.venv\Lib\site-packages\weaviate\embedded.py:186, in EmbeddedDB.check_supported_platform()
#     183 @staticmethod
#     184 def check_supported_platform() -> None:
#     185     if platform.system() in ["Windows"]:
# --> 186         raise WeaviateStartUpError(
#     187             f"""{platform.system()} is not supported with EmbeddedDB. Please upvote this feature request if you want
#     188              this: https://github.com/weaviate/weaviate/issues/3315"""  # noqa: E231
#     189         )
#
# WeaviateStartUpError: Windows is not supported with EmbeddedDB. Please upvote this feature request if you want
#                  this: https://github.com/weaviate/weaviate/issues/3315

# %%
#Check that weaviate is up and running

# ADD CODE HERE

# %%
#Delete the schema if it alredy exists
if client.schema.exists("Question"):
    client.schema.delete_class("Question")

# %%
#Create the schema that will house our data
class_obj = {
    "class": "Question",
    "vectorizer": "text2vec-openai",  
}

#Use the object above to create the schema
# ADD CODE HERE

# %%
with client.batch.configure() as batch:
    for i, d in enumerate(data):  # Batch import data
        
        print(f"importing question: {i+1}")
            
        #Specify the properties we want to import into Weviate
        
        # ADD CODE HERE
        
        #Add data to Weaviate
        
        # ADD CODE HERE

# %%
#Check how many objects we've loaded into the database

# ADD CODE HERE

# %%
#Extract and show any 3 questions and answers

# ADD CODE HERE
